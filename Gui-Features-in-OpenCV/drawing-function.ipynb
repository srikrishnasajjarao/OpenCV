# %% [markdown]
# ## Goal

# %% [markdown]
# 1. Learn to draw different geometric shapes with OpenCV
# 2. You will learn these functions : cv.line(), cv.circle() , cv.rectangle(), cv.ellipse(), cv.putText() etc.

# %% [markdown]
# **Drawing Line**

# %% [markdown]
# To draw a line, you need to pass **starting** and **ending** **coordinates** of line. We will create a black image and draw a blue line on it from top-left to bottom-right corners.

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# Create a black image
img = np.zeros((512,512,3),np.uint8)

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# Draw a diagonal blue line with thickness of 5 px
cv.line(img,(0,0),(511,511),(255,0,0),5)

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# Convert BGR to RGB for matplotlib display
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display the image in the notebook
plt.imshow(img_rgb)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# **Drawing Rectangle**

# %% [markdown]
# To draw a rectangle, you need **top-left corner** and **bottom-right corner** of rectangle. This time we will draw a green rectangle at the top-right corner of image.

# %%
cv.rectangle(img,(0,0),(511,511),(0,255,0),5)

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

cv.rectangle(img,(384,0),(510,128),(0,255,0),3)

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# Convert BGR to RGB for matplotlib display
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display the image in the notebook
plt.imshow(img_rgb)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# **Drawing Circle**

# %% [markdown]
# To draw a circle, you need its **center** coordinates and **radius**. We will draw a circle inside the rectangle drawn above.

# %%
cv.circle(img,(447,63), 63, (0,0,255), -1) # -1 is for fill

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

cv.circle(img,(447,447), 63, (0,0,255), 1) # 1 is for border

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# Convert BGR to RGB for matplotlib display
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display the image in the notebook
plt.imshow(img_rgb)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# **Drawing Ellipse**

# %% [markdown]
# To draw the ellipse, we need to pass several arguments. One argument is the **center** location (x,y). Next argument is **axes lengths** (major axis length, minor axis length). **angle** is the angle of rotation of ellipse in anti-clockwise direction. **startAngle** and **endAngle** denotes the starting and ending of ellipse arc measured in clockwise direction from major axis. i.e. giving values 0 and 360 gives the full ellipse.

# %%
cv.ellipse(img,(256,256),(100,50),0,0,180,255,-1) # 0 is for start angle and 180 is for end angle and -1 is for fill

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

cv.ellipse(img,(256,256),(100,50),0,180,360,255,-1) # 180 is for start angle and 360 is for end angle

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

cv.ellipse(img,(256,256),(100,50),0,180,360,(255,255,255),-1) # (255,255,255) is for color

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

cv.ellipse(img,(256,256),(100,50),0,180,360,(0,255,0),5,1) # 5 is for thickness and 1 is for border

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# Convert BGR to RGB for matplotlib display
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display the image in the notebook
plt.imshow(img_rgb)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# **Drawing Polygon**

# %% [markdown]
# To draw a polygon, first you need **coordinates of vertices**. Make those points into an array of shape ROWSx1x2 where ROWS are number of vertices and it should be of type int32. Here we draw a small polygon of with four vertices in yellow color.

# %%
pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
pts = pts.reshape((-1,1,2))
cv.polylines(img,[pts],True,(0,255,255),5)

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# Convert BGR to RGB for matplotlib display
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display the image in the notebook
plt.imshow(img_rgb)
plt.axis('off')  # Hide axes
plt.show()

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# Create a black canvas
img = np.zeros((512, 512, 3), np.uint8)

# Draw the outer circle (representing the logo body)
cv.circle(img, (256, 256), 150, (255, 165, 0), -1)  # Orange color (BGR)

# Draw the left eye (white circle)
cv.circle(img, (175, 200), 30, (255, 255, 255), -1)  # White color (BGR)

# Draw the right eye (white circle)
cv.circle(img, (335, 200), 30, (255, 255, 255), -1)  # White color (BGR)

# Draw the left pupil (black circle)
cv.circle(img, (175, 200), 15, (0, 0, 0), -1)  # Black color (BGR)

# Draw the right pupil (black circle)
cv.circle(img, (335, 200), 15, (0, 0, 0), -1)  # Black color (BGR)

# Draw the mouth (curve)
cv.ellipse(img, (256, 300), (80, 40), 0, 0, 180, (0, 0, 0), 5)  # Black color (BGR)

# Display the image
cv.imshow("OpenCV Logo", img)

# Wait until any key is pressed to close the image window
cv.waitKey(0)
cv.destroyAllWindows()

# Convert BGR to RGB for matplotlib display
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Plot both images side by side using subplots
plt.figure(figsize=(10, 5))

# First subplot for img (BGR)
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title("BGR Image")

# Second subplot for img_rgb (RGB)
plt.subplot(1, 2, 2)
plt.imshow(img_rgb)
plt.title("RGB Image")

# Display both images
plt.show()

# %%
import cv2
import numpy as np

#output image
img = np.full((360, 512, 3), 255, dtype="uint8")

img = cv2.ellipse(img, (256, 80), (60,60), 120,0,300,(0,0,255),-1)
img = cv2.ellipse(img, (256, 80), (20,20), 120,0,300,(255,255,255),-1)
img = cv2.ellipse(img, (176, 200), (60,60), 0,0,300,(0,255,0),-1)
img = cv2.ellipse(img, (176, 200), (20,20), 0,0,300,(255,255,255),-1)
img = cv2.ellipse(img, (336, 200), (60,60), 300,0,300,(255,0,0),-1)
img = cv2.ellipse(img, (336, 200), (20,20), 300,0,300,(255,255,255),-1)

font = cv2.FONT_HERSHEY_SIMPLEX
img = cv2.putText(img, "OpenCV", (196,296), font, 1, (0,0,0), 4, cv2.LINE_AA)

cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()


# Convert BGR to RGB for matplotlib display
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display the image in the notebook
plt.imshow(img_rgb)
